# %%
# ROOT

root_path = "C:/Users/jackm/Documents/GitHub/ms-capstone-TTS-natlang-styleprompts"

# %%
import pandas as pd

df = pd.read_csv(
    f"{root_path}/data/raw/libritts-p/data/metadata_w_style_prompt_tags_v230922.csv",
    sep=",",            # delimiter
    encoding="utf-8",   # or "latin1"
    na_values=["NA", ""],
)

# %%
df
# Out:
#                         item_name  spk_id gender   pitch speaking_speed  \
# 0       1001_134708_000013_000000    1001      M     low      very slow
# 1       1006_135212_000001_000004    1006      F  normal         normal
# 2       1006_135212_000001_000005    1006      F  normal         normal
# 3       1006_135212_000002_000000    1006      F    high         normal
# 4       1006_135212_000002_000001    1006      F  normal         normal
# ...                           ...     ...    ...     ...            ...
# 373862       98_199_000029_000001      98      F  normal         normal
# 373863       98_199_000029_000002      98      F  normal         normal
# 373864       98_199_000029_000003      98      F     low         normal
# 373865       98_199_000029_000004      98      F  normal           slow
# 373866       98_199_000030_000000      98      F    high         normal
#
#           energy                                     content_prompt  \
# 0            low  For man of you, your characteristic race, Here...
# 1         normal  Before laying it before the public it would be...
# 2         normal               These facts were briefly as follows:
# 3         normal  At five o'clock on the evening of the eighteen...
# 4           high  It was a rainy, squally day, which grew wilder...
# ...          ...                                                ...
# 373862    normal  Every five minutes, by removing some of the cr...
# 373863      high  She was now seen by many young men who had not...
# 373864       low  Not one, however, started with rapturous wonde...
# 373865       low  Yet Catherine was in very good looks, and had ...
# 373866  very low  She was looked at, however, and with some admi...
#
#                     style_prompt_key  raw_f0_mean  raw_f0_scale  raw_lf0_mean  \
# 0               M_p-low_s-slow_e-low       110.46         32.68          4.66
# 1       F_p-normal_s-normal_e-normal       214.32         28.74          5.36
# 2       F_p-normal_s-normal_e-normal       206.13         30.82          5.32
# 3         F_p-high_s-normal_e-normal       225.86         34.47          5.41
# 4         F_p-normal_s-normal_e-high       212.07         30.04          5.35
# ...                              ...          ...           ...           ...
# 373862  F_p-normal_s-normal_e-normal       210.52         51.84          5.32
# 373863    F_p-normal_s-normal_e-high       217.92         60.05          5.35
# 373864        F_p-low_s-normal_e-low       178.94         39.80          5.17
# 373865       F_p-normal_s-slow_e-low       220.13         46.15          5.37
# 373866       F_p-high_s-normal_e-low       237.24         96.06          5.39
#
#         raw_lf0_scale  raw_speaking_rate  raw_loudness_lufs  \
# 0                0.28               3.68             -21.41
# 1                0.13               5.14             -15.94
# 2                0.14               5.21             -17.26
# 3                0.14               4.92             -14.94
# 4                0.13               5.08             -15.34
# ...               ...                ...                ...
# 373862           0.25               5.49             -19.72
# 373863           0.27               4.80             -18.46
# 373864           0.19               4.64             -20.00
# 373865           0.21               4.47             -21.29
# 373866           0.39               5.16             -19.47
#
#         raw_loudness_mean  raw_loudness_scale  invalid
# 0                   -2.92                3.62        0
# 1                   -1.24                3.05        0
# 2                   -1.25                2.84        0
# 3                   -1.65                3.43        0
# 4                   -0.90                2.91        0
# ...                   ...                 ...      ...
# 373862              -1.80                3.41        0
# 373863              -0.81                2.56        0
# 373864              -2.51                3.54        0
# 373865              -2.49                3.43        0
# 373866              -2.56                3.90        0
#
# [373867 rows x 17 columns]
