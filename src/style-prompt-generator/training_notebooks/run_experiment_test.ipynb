# %% [markdown]
# # Environment Setup

# %% [markdown]
# important step: Set Weights & Biases api key in colab keys

# %% [markdown]
# I used this model to test out building and training the model. I used colab's GPUs.

# %% [markdown]
# ### Packages

# %%
# %pip install transformers h5py pandas pyarrow protobuf

# %%
# %pip install torch

# install cuda on windows
# %pip install torch --index-url https://download.pytorch.org/whl/cu126

# %pip install bert_score sacrebleu rouge_score sentence_transformers -q
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 11.0 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done

# %% [markdown]
# ### Mount drive for accessing data in Colab
#
# Skip if cloning github for custom code

# %%
from google.colab import drive
drive.mount('/content/drive')

# Add path so imports work
import sys
sys.path.insert(0, "/content/drive/MyDrive/capstone/Colab_resources/style-prompt-generator")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Clone GitHub Repository and Add to System Path

# %%
# --- Configuration for your GitHub Repository ---
GITHUB_REPO_URL = "https://github.com/JackMclaughlin424/imgs789-project_graph-dialogue-modeling.git"
REPO_NAME = "imgs789-project_graph-dialogue-modeling"
COMMIT_HASH = None #"your_commit_hash"
SUBDIRECTORY = "src"

# %% [markdown]
# **Clear GitHub Repository**

# %%
import shutil
import os

# Ensure REPO_NAME is defined (it should be from previous cells)
if 'REPO_NAME' in globals() and REPO_NAME:
    repo_path = f'/content/{REPO_NAME}'
    if os.path.exists(repo_path):
        print(f'Removing {repo_path}...')
        shutil.rmtree(repo_path)
        print(f'{repo_path} removed successfully.')
    else:
        print(f'Repository directory {repo_path} does not exist.')
else:
    print('REPO_NAME variable not found or is empty. Please ensure the repository name is set.')
# Out:
# Repository directory /content/ms-capstone-TTS-natlang-styleprompts does not exist.

# %% [markdown]
# **Clone repo**

# %%
import os
import sys


# Clone the repository
# !git clone {GITHUB_REPO_URL} /content/{REPO_NAME}

# Navigate into the cloned directory
# %cd /content/{REPO_NAME}

# Checkout a specific commit if provided
if COMMIT_HASH:
    print(f"Checking out commit: {COMMIT_HASH}")
    # !git checkout {COMMIT_HASH}
else:
    print("Using the latest commit on the default branch.")

# Navigate back to the content directory (or stay in the repo root if that's where the code is)
# %cd /content

# Add the repository (or its subdirectory) to sys.path
repo_path = f"/content/{REPO_NAME}"
if SUBDIRECTORY:
    repo_path = os.path.join(repo_path, SUBDIRECTORY)

if repo_path not in sys.path:
    sys.path.insert(0, repo_path)
    print(f"Added {repo_path} to sys.path")
else:
    print(f"{repo_path} is already in sys.path")

print("Current sys.path:")
for p in sys.path:
    print(p)
# Out:
# Cloning into '/content/ms-capstone-TTS-natlang-styleprompts'...
# remote: Enumerating objects: 1629, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 1629 (delta 20), reused 26 (delta 13), pack-reused 1594 (from 2)
# Receiving objects: 100% (1629/1629), 5.28 MiB | 22.90 MiB/s, done.
# Resolving deltas: 100% (1184/1184), done.
# /content/ms-capstone-TTS-natlang-styleprompts
# Using the latest commit on the default branch.
# /content
# Added /content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator to sys.path
# Current sys.path:
# /content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator
# /content/drive/MyDrive/capstone/Colab_resources/style-prompt-generator
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ### Set W&B API Key from Colab Secrets
#
# This cell will retrieve your Weights & Biases API key from Colab's 'Secrets' and set it as an environment variable, making it accessible to `os.environ.get()` within your `train.py` script.

# %%
from google.colab import userdata
import os

# Retrieve the API key from Colab secrets
wandb_api_key = userdata.get('WANDB_API_KEY')

if wandb_api_key:
    os.environ['WANDB_API_KEY'] = wandb_api_key
    print("W&B API key loaded from Colab secrets and set as environment variable.")
else:
    print("W&B_API_KEY not found in Colab secrets. Please ensure it's set there.")
# Out:
# W&B API key loaded from Colab secrets and set as environment variable.

# %% [markdown]
# set hf token

# %%
HF_TOKEN = userdata.get('HF_TOKEN')

if HF_TOKEN:
    os.environ['HF_TOKEN'] = HF_TOKEN
    print("HF_TOKEN loaded from Colab secrets and set as environment variable.")
else:
    print("HF_TOKEN not found in Colab secrets. Please ensure it's set there.")
# Out:
# HF_TOKEN loaded from Colab secrets and set as environment variable.

# %%
blurp # force fail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_432/3689156905.py in <cell line: 0>()
# ----> 1 blurp # force fail
#
# NameError: name 'blurp' is not defined

# %% [markdown]
# # Training Model

# %%
import sys

sys.argv = [
    "run_experiment.py",
    "--config",       f"/content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator/configs/best_experiment_config.json",
    "--num_trials",        "1",
    "--override",
    "num_epochs=1",
    "h5_path=/content/drive/MyDrive/capstone/Colab_resources/data/merged_audio_full.h5",
    "meta_path=/content/drive/MyDrive/capstone/Colab_resources/data/merged_metadata_full.parquet"
]

# %%
import shutil
import os

wandb_cache_path = '/content/wandb'

if os.path.exists(wandb_cache_path):
    print(f'Removing wandb cache directory: {wandb_cache_path}...')
    shutil.rmtree(wandb_cache_path)
    print(f'Wandb cache directory {wandb_cache_path} removed successfully.')
else:
    print(f'Wandb cache directory {wandb_cache_path} does not exist.')
# Out:
# Wandb cache directory /content/wandb does not exist.

# %%
# my scripts cloned from github
from run_experiment import main
main()
# Out:
# INFO:run_experiment:No experiment config - running 1 baseline trials on base config.
# INFO:run_experiment:=== baseline trial=1/1  seed=191664964 ===
# INFO:run_experiment:Run config: {
#   "h5_path": "/content/drive/MyDrive/capstone/Colab_resources/data/merged_audio_full.h5",
#   "meta_path": "/content/drive/MyDrive/capstone/Colab_resources/data/merged_metadata_full.parquet",
#   "output_dir": "runs/exp",
#   "num_turns": 3,
#   "max_len_sec": 15,
#   "d_model": 768,
#   "num_ctx_layers": 2,
#   "num_spk_layers": 2,
#   "dim_feedforward": 2048,
#   "nhead": 8,
#   "llm_repo": "meta-llama/Llama-3.2-3B-Instruct",
#   "llm_dim": 3072,
#   "num_prefix_tokens": 10,
#   "num_mapping_layers": 2,
#   "mapping_nhead": 8,
#   "system_prompt": "Speaking style:",
#   "max_prompt_tokens": 128,
#   "max_style_desc_tokens": 50,
#   "max_new_tokens": 50,
#   "num_unfrozen_bert": 0,
#   "num_unfrozen_wavlm": 0,
#   "dialogue_pooler": "attentive",
#   "batch_size": 16,
#   "num_epochs": 1,
#   "learning_rate": 8e-05,
#   "weight_decay": 0.004,
#   "grad_clip": 1.0,
#   "warmup_ratio": 0.16,
#   "lr_schedule": "linear",
#   "dropout": 0.1,
#   "val_split": 0.1,
#   "eval_every_n_epochs": 1,
#   "save_every_n_epochs": 1,
#   "keep_last_n_ckpts": 2,
#   "early_stopping_patience": 3,
#   "early_stopping_min_delta": 0.001,
#   "seed": 191664964,
#   "num_workers": 0,
#   "sample_rate": 16000,
#   "log_every_n_steps": 50,
#   "run_name": null,
#   "use_wandb": true,
#   "wandb_project": "final-style-prompt-gen",
#   "wandb_entity": "jdm8943-rochester-institute-of-technology",
#   "_comment_param_section_dataset": "Dataset parameters",
#   "data_source": "both",
#   "max_test_convos": 250,
#   "_comment_param_section_encoder": "Dialogue encoder parameters",
#   "_comment_param_section_llm_peft": "LLM / PEFT parameters",
#   "_comment_param_section_training": "Training parameters",
#   "_comment_param_section_wandb": "W&B settings"
# }
# Override: num_epochs = 1
# Override: h5_path = '/content/drive/MyDrive/capstone/Colab_resources/data/merged_audio_full.h5'
# Override: meta_path = '/content/drive/MyDrive/capstone/Colab_resources/data/merged_metadata_full.parquet'
# INFO:run_experiment:Split sizes  trainval_conv_ids=2170  test_chains=400  expresso=200  styletalk=200
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: jdm8943 (jdm8943-rochester-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.26.1
# Run data is saved locally in <code>/content/wandb/run-20260428_194135-1iss4jc1</code>
# Syncing run <strong><a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen/runs/1iss4jc1' target="_blank">test_trial0</a></strong> to <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen</a>
#  View run at <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen/runs/1iss4jc1' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/final-style-prompt-gen/runs/1iss4jc1</a>
# INFO:sweep:Final train_ds chain count: 4351
# INFO:sweep:Building model...
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: google-bert/bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:sweep:BERT: 0 encoder layer(s) unfrozen
# preprocessor_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/248 [00:00<?, ?it/s]
# INFO:sweep:WavLM: 0 encoder layer(s) unfrozen
# model.safetensors:   0%|          | 0.00/378M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# INFO:sweep:Trainable parameters: 133,878,029
