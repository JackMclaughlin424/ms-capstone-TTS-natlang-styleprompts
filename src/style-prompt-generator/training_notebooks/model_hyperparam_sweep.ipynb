# %% [markdown]
# # Environment Setup

# %% [markdown]
# important step: Set Weights & Biases api key in colab keys

# %% [markdown]
# I used this model to test out building and training the model. I used colab's GPUs.

# %% [markdown]
# ### Packages

# %%
# %pip install transformers h5py pandas pyarrow protobuf

# %%
# %pip install torch

# install cuda on windows
# %pip install torch --index-url https://download.pytorch.org/whl/cu126

# %pip install bert_score
# Out:
# Requirement already satisfied: bert_score in /usr/local/lib/python3.12/dist-packages (0.3.13)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.10.0+cu128)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert_score) (5.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert_score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.12/dist-packages (from bert_score) (4.67.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert_score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert_score) (26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert_score) (2025.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert_score) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.0.0->bert_score) (1.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (1.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert_score) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert_score) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert_score) (2026.2.25)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (0.24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers>=3.0.0->bert_score) (0.1.2)

# %% [markdown]
# ### Mount drive for accessing data in Colab
#
# Skip if cloning github for custom code

# %%
from google.colab import drive
drive.mount('/content/drive')

# Add path so imports work
import sys
sys.path.insert(0, "/content/drive/MyDrive/capstone/Colab_resources/style-prompt-generator")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Clone GitHub Repository and Add to System Path

# %%
# --- Configuration for your GitHub Repository ---
GITHUB_REPO_URL = "https://github.com/JackMclaughlin424/ms-capstone-TTS-natlang-styleprompts.git" # Replace with your GitHub repository URL
REPO_NAME = "ms-capstone-TTS-natlang-styleprompts"
COMMIT_HASH = None #"your_commit_hash"
SUBDIRECTORY = "src/style-prompt-generator" # If your project code is in a subdirectory (e.g., 'Colab resources/style-prompt-generator'), specify it here. Otherwise, set to None or an empty string.

# %% [markdown]
# **Clear GitHub Repository**

# %%
import shutil
import os

# Ensure REPO_NAME is defined (it should be from previous cells)
if 'REPO_NAME' in globals() and REPO_NAME:
    repo_path = f'/content/{REPO_NAME}'
    if os.path.exists(repo_path):
        print(f'Removing {repo_path}...')
        shutil.rmtree(repo_path)
        print(f'{repo_path} removed successfully.')
    else:
        print(f'Repository directory {repo_path} does not exist.')
else:
    print('REPO_NAME variable not found or is empty. Please ensure the repository name is set.')
# Out:
# Removing /content/ms-capstone-TTS-natlang-styleprompts...
# /content/ms-capstone-TTS-natlang-styleprompts removed successfully.

# %% [markdown]
# **Clone repo**

# %%
import os
import sys


# Clone the repository
# !git clone {GITHUB_REPO_URL} /content/{REPO_NAME}

# Navigate into the cloned directory
# %cd /content/{REPO_NAME}

# Checkout a specific commit if provided
if COMMIT_HASH:
    print(f"Checking out commit: {COMMIT_HASH}")
    # !git checkout {COMMIT_HASH}
else:
    print("Using the latest commit on the default branch.")

# Navigate back to the content directory (or stay in the repo root if that's where the code is)
# %cd /content

# Add the repository (or its subdirectory) to sys.path
repo_path = f"/content/{REPO_NAME}"
if SUBDIRECTORY:
    repo_path = os.path.join(repo_path, SUBDIRECTORY)

if repo_path not in sys.path:
    sys.path.insert(0, repo_path)
    print(f"Added {repo_path} to sys.path")
else:
    print(f"{repo_path} is already in sys.path")

print("Current sys.path:")
for p in sys.path:
    print(p)
# Out:
# Cloning into '/content/ms-capstone-TTS-natlang-styleprompts'...
# remote: Enumerating objects: 1069, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 1069 (delta 106), reused 94 (delta 53), pack-reused 918 (from 1)
# Receiving objects: 100% (1069/1069), 3.51 MiB | 23.66 MiB/s, done.
# Resolving deltas: 100% (754/754), done.
# /content/ms-capstone-TTS-natlang-styleprompts
# Using the latest commit on the default branch.
# /content
# Added /content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator to sys.path
# Current sys.path:
# /content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator
# /content/drive/MyDrive/capstone/Colab_resources/style-prompt-generator
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython

# %% [markdown]
# ### Set W&B API Key from Colab Secrets
#
# This cell will retrieve your Weights & Biases API key from Colab's 'Secrets' and set it as an environment variable, making it accessible to `os.environ.get()` within your `train.py` script.

# %%
from google.colab import userdata
import os

# Retrieve the API key from Colab secrets
wandb_api_key = userdata.get('WANDB_API_KEY')

if wandb_api_key:
    os.environ['WANDB_API_KEY'] = wandb_api_key
    print("W&B API key loaded from Colab secrets and set as environment variable.")
else:
    print("W&B_API_KEY not found in Colab secrets. Please ensure it's set there.")
# Out:
# W&B API key loaded from Colab secrets and set as environment variable.

# %% [markdown]
# set hf token

# %%
HF_TOKEN = userdata.get('HF_TOKEN')

if HF_TOKEN:
    os.environ['HF_TOKEN'] = HF_TOKEN
    print("HF_TOKEN loaded from Colab secrets and set as environment variable.")
else:
    print("HF_TOKEN not found in Colab secrets. Please ensure it's set there.")
# Out:
# HF_TOKEN loaded from Colab secrets and set as environment variable.

# %% [markdown]
# # Training Model

# %%
import sys

sys.argv = [
    "sweep.py",
    "--config",       f"/content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator/default_sweep_config.json",
    "--sweep_values", f"/content/ms-capstone-TTS-natlang-styleprompts/src/style-prompt-generator/default_sweep_values.json",
    "--n_folds",      "5",
    "--count",        "10",
    # "--sweep_id",   "blablabla",   # uncomment to join an existing sweep
]

# %%
blurp # force fail
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_14822/3689156905.py in <cell line: 0>()
# ----> 1 blurp # force fail
#
# NameError: name 'blurp' is not defined

# %%
import shutil
import os

wandb_cache_path = '/content/wandb'

if os.path.exists(wandb_cache_path):
    print(f'Removing wandb cache directory: {wandb_cache_path}...')
    shutil.rmtree(wandb_cache_path)
    print(f'Wandb cache directory {wandb_cache_path} removed successfully.')
else:
    print(f'Wandb cache directory {wandb_cache_path} does not exist.')
# Out:
# Removing wandb cache directory: /content/wandb...
# Wandb cache directory /content/wandb removed successfully.

# %%
# my scripts cloned from github
from sweep import main
main()
# Out:
# INFO:sweep:2477 unique conversations → 2230 train/val  |  247 test (held-out)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# INFO:sweep:Created sweep: dk5jhhgt
# Create sweep with ID: dk5jhhgt
# Sweep URL: https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/sweeps/dk5jhhgt
# wandb: Agent Starting Run: 23w03nih with config:
# wandb: 	dropout: 0.1
# wandb: 	learning_rate: 5.3706599324402515e-05
# wandb: 	num_turns: 5
# wandb: 	num_unfrozen_embedder_layers: 1
# wandb: 	system_prompt:
# wandb: 	weight_decay: 0.00011083983014082208
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: jdm8943 (jdm8943-rochester-institute-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260411_212751-23w03nih</code>
# Syncing run <strong><a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/runs/23w03nih' target="_blank">glad-sweep-1</a></strong> to <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/sweeps/dk5jhhgt' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/sweeps/dk5jhhgt</a>
#  View project at <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen</a>
#  View sweep at <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/sweeps/dk5jhhgt' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/sweeps/dk5jhhgt</a>
#  View run at <a href='https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/runs/23w03nih' target="_blank">https://wandb.ai/jdm8943-rochester-institute-of-technology/sweep-style-prompt-gen/runs/23w03nih</a>
# INFO:sweep:=== Fold 1/5 ===
# INFO:sweep:  4104 train chains  |  996 val chains
# INFO:sweep:Building model...
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: google-bert/bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# INFO:sweep:BERT: 1 encoder layer(s) unfrozen
# Loading weights:   0%|          | 0/248 [00:00<?, ?it/s]
# INFO:sweep:WavLM: 1 encoder layer(s) unfrozen
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# INFO:sweep:Trainable parameters: 349,488,929
# INFO:sweep:epoch 0 - batch 100/513 - step 100 | loss 1.5079  lr 6.98e-06  grad_norm 1.000  00:54<03:43
# INFO:sweep:epoch 0 - batch 200/513 - step 200 | loss 1.3345  lr 1.40e-05  grad_norm 1.000  01:45<02:44
# INFO:sweep:epoch 0 - batch 300/513 - step 300 | loss 0.8215  lr 2.10e-05  grad_norm 1.000  02:36<01:51
# INFO:sweep:epoch 0 - batch 400/513 - step 400 | loss 1.0789  lr 2.79e-05  grad_norm 1.000  03:27<00:58
# INFO:sweep:epoch 0 - batch 500/513 - step 500 | loss 0.9677  lr 3.49e-05  grad_norm 1.000  04:18<00:06
# INFO:sweep:TRAIN epoch 0 avg loss: 1.5568
# INFO:sweep:VAL epoch 0 avg loss: 0.9228
# INFO:sweep:epoch 1 - batch 87/513 - step 600 | loss 1.1064  lr 4.19e-05  grad_norm 1.000  00:45<03:44
# INFO:sweep:epoch 1 - batch 187/513 - step 700 | loss 1.3087  lr 4.89e-05  grad_norm 1.000  01:37<02:49
# INFO:sweep:epoch 1 - batch 287/513 - step 800 | loss 1.2416  lr 5.37e-05  grad_norm 1.000  02:28<01:56
# INFO:sweep:epoch 1 - batch 387/513 - step 900 | loss 1.1632  lr 5.37e-05  grad_norm 1.000  03:19<01:05
# INFO:sweep:epoch 1 - batch 487/513 - step 1000 | loss 1.0746  lr 5.36e-05  grad_norm 1.000  04:11<00:13
# INFO:sweep:TRAIN epoch 1 avg loss: 1.0771
# INFO:sweep:VAL epoch 1 avg loss: 0.8113
# INFO:sweep:epoch 2 - batch 74/513 - step 1100 | loss 1.2070  lr 5.34e-05  grad_norm 1.000  00:39<03:53
# INFO:sweep:epoch 2 - batch 174/513 - step 1200 | loss 1.1304  lr 5.32e-05  grad_norm 1.000  01:30<02:56
# INFO:sweep:epoch 2 - batch 274/513 - step 1300 | loss 1.0593  lr 5.29e-05  grad_norm 1.000  02:22<02:04
# INFO:sweep:epoch 2 - batch 374/513 - step 1400 | loss 0.4768  lr 5.26e-05  grad_norm 1.000  03:13<01:11
# INFO:sweep:epoch 2 - batch 474/513 - step 1500 | loss 0.7218  lr 5.22e-05  grad_norm 1.000  04:05<00:20
# INFO:sweep:TRAIN epoch 2 avg loss: 0.9916
# INFO:sweep:VAL epoch 2 avg loss: 0.7845
# INFO:sweep:epoch 3 - batch 61/513 - step 1600 | loss 0.8946  lr 5.18e-05  grad_norm 1.000  00:32<04:03
# INFO:sweep:epoch 3 - batch 161/513 - step 1700 | loss 1.0088  lr 5.13e-05  grad_norm 1.000  01:24<03:04
# INFO:sweep:epoch 3 - batch 261/513 - step 1800 | loss 1.0587  lr 5.08e-05  grad_norm 1.000  02:15<02:10
# INFO:sweep:epoch 3 - batch 361/513 - step 1900 | loss 1.2336  lr 5.02e-05  grad_norm 1.000  03:06<01:18
# INFO:sweep:epoch 3 - batch 461/513 - step 2000 | loss 1.0770  lr 4.96e-05  grad_norm 1.000  03:57<00:26
# INFO:sweep:TRAIN epoch 3 avg loss: 0.9579
# INFO:sweep:VAL epoch 3 avg loss: 0.7597
# INFO:sweep:epoch 4 - batch 48/513 - step 2100 | loss 0.7590  lr 4.90e-05  grad_norm 1.000  00:26<04:12
# INFO:sweep:epoch 4 - batch 148/513 - step 2200 | loss 0.9040  lr 4.82e-05  grad_norm 1.000  01:17<03:10
# INFO:sweep:epoch 4 - batch 248/513 - step 2300 | loss 1.1263  lr 4.75e-05  grad_norm 1.000  02:08<02:17
# INFO:sweep:epoch 4 - batch 348/513 - step 2400 | loss 0.9818  lr 4.67e-05  grad_norm 1.000  02:59<01:25
# INFO:sweep:epoch 4 - batch 448/513 - step 2500 | loss 1.0361  lr 4.58e-05  grad_norm 1.000  03:50<00:33
# INFO:sweep:TRAIN epoch 4 avg loss: 0.9537
# INFO:sweep:VAL epoch 4 avg loss: 0.7861
# INFO:sweep:epoch 5 - batch 35/513 - step 2600 | loss 1.0924  lr 4.50e-05  grad_norm 1.000  00:19<04:22
# INFO:sweep:epoch 5 - batch 135/513 - step 2700 | loss 0.4931  lr 4.40e-05  grad_norm 1.000  01:10<03:18
# INFO:sweep:epoch 5 - batch 235/513 - step 2800 | loss 0.8718  lr 4.31e-05  grad_norm 1.000  02:02<02:24
# INFO:sweep:epoch 5 - batch 335/513 - step 2900 | loss 0.9086  lr 4.21e-05  grad_norm 1.000  02:53<01:32
# INFO:sweep:epoch 5 - batch 435/513 - step 3000 | loss 1.2245  lr 4.11e-05  grad_norm 1.000  03:45<00:40
# INFO:sweep:TRAIN epoch 5 avg loss: 0.9715
# INFO:sweep:VAL epoch 5 avg loss: 0.7567
# INFO:sweep:epoch 6 - batch 22/513 - step 3100 | loss 0.9234  lr 4.00e-05  grad_norm 1.000  00:12<04:39
# INFO:sweep:epoch 6 - batch 122/513 - step 3200 | loss 1.0642  lr 3.90e-05  grad_norm 1.000  01:03<03:24
# INFO:sweep:epoch 6 - batch 222/513 - step 3300 | loss 0.9552  lr 3.79e-05  grad_norm 1.000  01:55<02:31
# INFO:sweep:epoch 6 - batch 322/513 - step 3400 | loss 1.0568  lr 3.67e-05  grad_norm 1.000  02:47<01:39
# INFO:sweep:epoch 6 - batch 422/513 - step 3500 | loss 0.9237  lr 3.56e-05  grad_norm 1.000  03:38<00:47
# INFO:sweep:TRAIN epoch 6 avg loss: 0.9218
# INFO:sweep:VAL epoch 6 avg loss: 0.7445
# INFO:sweep:epoch 7 - batch 9/513 - step 3600 | loss 0.9781  lr 3.44e-05  grad_norm 1.000  00:05<05:12
# INFO:sweep:epoch 7 - batch 109/513 - step 3700 | loss 0.8405  lr 3.33e-05  grad_norm 1.000  00:57<03:31
# INFO:sweep:epoch 7 - batch 209/513 - step 3800 | loss 0.9700  lr 3.21e-05  grad_norm 1.000  01:48<02:37
# wandb: Ctrl + C detected. Stopping sweep.
